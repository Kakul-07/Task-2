# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score
)

# %%
df = pd.read_csv("../Dataset/dataset.csv")

# %%
df["Security_Type"] = df["Security_Type"].replace("Indriect", "Indirect")

# %%
X = df.drop(columns=["ID", "year", "Status"])
y = df["Status"]
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (148670, 31)
# y shape: (148670,)

# %%
print(y.value_counts())
print("\nPercentage:")
print(y.value_counts(normalize=True) * 100)
# Out:
# Status
# 0    112031
# 1     36639
# Name: count, dtype: int64
#
# Percentage:
# Status
# 0    75.355485
# 1    24.644515
# Name: proportion, dtype: float64

# %%
majority_class = y.mode()[0]
baseline_predictions = np.full(len(y), majority_class)
print("Baseline class:", majority_class)
print("Baseline accuracy:", accuracy_score(y, baseline_predictions))
# Out:
# Baseline class: 0
# Baseline accuracy: 0.7535548530302011

# %%
print(classification_report(y, baseline_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86    112031
#            1       0.00      0.00      0.00     36639
#
#     accuracy                           0.75    148670
#    macro avg       0.38      0.50      0.43    148670
# weighted avg       0.57      0.75      0.65    148670
# /Users/kakulrajput/Documents/G-Task2/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/kakulrajput/Documents/G-Task2/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
